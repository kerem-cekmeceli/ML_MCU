# %% [markdown]
# Includes:

# %%
# %reload_ext autoreload
# %autoreload 2

import seaborn as sn
import os
import matplotlib.pyplot as plt
from data_paths import get_file_paths_ordered
from pre_process import *
from models import *

# %% [markdown]
# Number of speakers and the percentage of the available samples to use to consider:

# %%
MODEL_NAME = '8speakers'

CSV_DIR = 'csv/'
MODEL_DIR = 'Models/'+ f'{MODEL_NAME}/'
print(MODEL_DIR)
if not os.path.exists(MODEL_DIR):
    print("Creating directory for model : ", MODEL_NAME)
    os.makedirs(MODEL_DIR)

TFLITE_MODEL_NAME = 'tflite_'+ MODEL_NAME
C_MODEL_NAME = MODEL_NAME
print("Model names : ", MODEL_NAME,TFLITE_MODEL_NAME, C_MODEL_NAME)


# Number of speakers and the percentage of the available samples to use to consider:
NB_SPEAKERS = 8
dataset_percentage = 1 # 0.85
print("Number of speakers : ", NB_SPEAKERS)
# Out:
# Models/8speakers/
# Model names :  8speakers tflite_8speakers 8speakers
# Number of speakers :  8

# %% [markdown]
# Read data:

# %%
paths_train, paths_test, y_train_l, y_test_l, all_paths_l = \
    get_file_paths_ordered(num_speaker=num_speakers, test_ratio=0.2, balanced_dataset=True, plot_data=True)

slice_len = choose_tot_slice_len(paths=all_paths_l, visualize=True)

f_s, x_train, y_train, x_test, y_test = get_data_tensors(paths_train=paths_train, paths_test=paths_test, 
                                                         y_train_l=y_train_l, y_test_l=y_test_l,
                                                         tot_slice_len=slice_len,
                                                         used_train_sz_rat=dataset_percentage, 
                                                         used_test_sz_rat=1.,
                                                         segmentLength=segmentLength)
# Out:
# Total number of speakers in the original dataset: 20
# Original number of files per speaker :  [1002, 656, 589, 570, 489, 476, 468, 426]
# Training number of files per speaker :  3180
# Visualization of the samples ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 3975/3975 [00:13<00:00, 304.53it/s]
# C:\Apps\Anaconda3\envs\ml\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# 100%|█████████████████████████████████████████████████████████████████████████████| 3180/3180 [00:08<00:00, 375.67it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 795/795 [00:03<00:00, 215.43it/s]

# %% [markdown]
# @TODO play some of the speakers as an example

# %% [markdown]
# Pre-Processing:

# %%
f_low=80.
f_up=7600.
num_mel_bins=80
num_mfcc=13

x_train_mfcc = compute_mfccs(x_train, frame_length=segmentLength, sample_rate=f_s, 
                             lower_edge_hertz=f_low, upper_edge_hertz=f_up,
                             num_mel_bins=num_mel_bins, num_mfcc=num_mfcc)
x_test_mfcc  = compute_mfccs(x_test, frame_length=segmentLength, sample_rate=f_s, 
                             lower_edge_hertz=f_low, upper_edge_hertz=f_up,
                             num_mel_bins=num_mel_bins, num_mfcc=num_mfcc)

# %% [markdown]
# # Model:

# %%
train_set = x_train_mfcc
test_set = x_test_mfcc

# %%
model_idx = 0
input_shape = train_set.shape
model = get_model(input_shape=input_shape, nb_classes=num_speakers, model_idx=model_idx)
model.build(input_shape=input_shape)
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_3 (Normalizat  (3180, 171, 13, 1)       3
#  ion)
#
#  conv2d_12 (Conv2D)          (3180, 171, 13, 3)        30
#
#  batch_normalization_12 (Bat  (3180, 171, 13, 3)       12
#  chNormalization)
#
#  activation_18 (Activation)  (3180, 171, 13, 3)        0
#
#  conv2d_13 (Conv2D)          (3180, 86, 7, 16)         448
#
#  batch_normalization_13 (Bat  (3180, 86, 7, 16)        64
#  chNormalization)
#
#  activation_19 (Activation)  (3180, 86, 7, 16)         0
#
#  max_pooling2d_6 (MaxPooling  (3180, 43, 3, 16)        0
#  2D)
#
#  conv2d_14 (Conv2D)          (3180, 22, 2, 32)         4640
#
#  batch_normalization_14 (Bat  (3180, 22, 2, 32)        128
#  chNormalization)
#
#  activation_20 (Activation)  (3180, 22, 2, 32)         0
#
#  max_pooling2d_7 (MaxPooling  (3180, 11, 1, 32)        0
#  2D)
#
#  conv2d_15 (Conv2D)          (3180, 6, 1, 48)          13872
#
#  batch_normalization_15 (Bat  (3180, 6, 1, 48)         192
#  chNormalization)
#
#  activation_21 (Activation)  (3180, 6, 1, 48)          0
#
#  global_average_pooling2d_3   (3180, 48)               0
#  (GlobalAveragePooling2D)
#
#  flatten_3 (Flatten)         (3180, 48)                0
#
#  dense_6 (Dense)             (3180, 8)                 392
#
#  activation_22 (Activation)  (3180, 8)                 0
#
#  dense_7 (Dense)             (3180, 8)                 72
#
#  activation_23 (Activation)  (3180, 8)                 0
#
# =================================================================
# Total params: 19,853
# Trainable params: 19,652
# Non-trainable params: 201
# _________________________________________________________________

# %% [markdown]
# Define learning parameters:

# %%
batchSize = 32 #8 # nb of togetherly processed segments(of 1024 samples each) 
epochs = 100 #40 # nb of back propagations
loss_fct = 'sparse_categorical_crossentropy'

# %% [markdown]
# Compile the model and Fit the Data:

# %%
from tensorflow import keras

model.compile(
    loss=loss_fct, 
    optimizer=tf.keras.optimizers.Adam(), 
    metrics=['accuracy']
)

callbacks = [
    keras.callbacks.(MODEL_DIR + MODEL_NAME + '_best.h5',save_best_only=True),
    #keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=20, min_lr=1.0e-5),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=20, verbose=1),       
]

history_keras = model.fit(x=train_set, 
                          y=y_train, 
                          batch_size=batchSize, 
                          epochs=epochs, 
                          validation_split=0.2,
                          callbacks = callbacks, )
# Out:
# Epoch 1/100
# 80/80 [==============================] - 4s 26ms/step - loss: 1.8219 - accuracy: 0.2980 - val_loss: 2.0877 - val_accuracy: 0.1211
# Epoch 2/100
# 80/80 [==============================] - 2s 22ms/step - loss: 1.2963 - accuracy: 0.4996 - val_loss: 2.7127 - val_accuracy: 0.1761
# Epoch 3/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.8136 - accuracy: 0.7355 - val_loss: 4.1109 - val_accuracy: 0.2374
# Epoch 4/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.5493 - accuracy: 0.8494 - val_loss: 4.8101 - val_accuracy: 0.2516
# Epoch 5/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.4039 - accuracy: 0.8821 - val_loss: 3.4338 - val_accuracy: 0.4245
# Epoch 6/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.3217 - accuracy: 0.9080 - val_loss: 1.8741 - val_accuracy: 0.4874
# Epoch 7/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.2563 - accuracy: 0.9222 - val_loss: 0.9039 - val_accuracy: 0.6950
# Epoch 8/100
# 80/80 [==============================] - 2s 21ms/step - loss: 0.2162 - accuracy: 0.9351 - val_loss: 1.7622 - val_accuracy: 0.5362
# Epoch 9/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.1911 - accuracy: 0.9410 - val_loss: 0.3401 - val_accuracy: 0.8978
# Epoch 10/100
# 80/80 [==============================] - 2s 21ms/step - loss: 0.1624 - accuracy: 0.9540 - val_loss: 0.5913 - val_accuracy: 0.8208
# Epoch 11/100
# 80/80 [==============================] - 2s 21ms/step - loss: 0.1466 - accuracy: 0.9583 - val_loss: 0.3542 - val_accuracy: 0.8947
# Epoch 12/100
# 80/80 [==============================] - 2s 21ms/step - loss: 0.1375 - accuracy: 0.9595 - val_loss: 0.5771 - val_accuracy: 0.7972
# Epoch 13/100
# 80/80 [==============================] - 2s 23ms/step - loss: 0.1210 - accuracy: 0.9642 - val_loss: 0.2505 - val_accuracy: 0.9261
# Epoch 14/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.1024 - accuracy: 0.9729 - val_loss: 0.5995 - val_accuracy: 0.8129
# Epoch 15/100
# 80/80 [==============================] - 2s 28ms/step - loss: 0.0981 - accuracy: 0.9717 - val_loss: 0.5854 - val_accuracy: 0.8223
# Epoch 16/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.0777 - accuracy: 0.9784 - val_loss: 1.6730 - val_accuracy: 0.6651
# Epoch 17/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.0713 - accuracy: 0.9792 - val_loss: 0.3104 - val_accuracy: 0.8994
# Epoch 18/100
# 80/80 [==============================] - 2s 21ms/step - loss: 0.0693 - accuracy: 0.9839 - val_loss: 0.7615 - val_accuracy: 0.7642
# Epoch 19/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.0638 - accuracy: 0.9831 - val_loss: 0.2244 - val_accuracy: 0.9324
# Epoch 20/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.0774 - accuracy: 0.9776 - val_loss: 1.6920 - val_accuracy: 0.6368
# Epoch 21/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.0644 - accuracy: 0.9831 - val_loss: 0.7511 - val_accuracy: 0.7814
# Epoch 22/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.0491 - accuracy: 0.9870 - val_loss: 0.6999 - val_accuracy: 0.7752
# Epoch 23/100
# 80/80 [==============================] - 2s 24ms/step - loss: 0.0320 - accuracy: 0.9949 - val_loss: 0.2946 - val_accuracy: 0.9104
# Epoch 24/100
# 80/80 [==============================] - 2s 21ms/step - loss: 0.0428 - accuracy: 0.9874 - val_loss: 0.4306 - val_accuracy: 0.8695
# Epoch 25/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.0388 - accuracy: 0.9886 - val_loss: 0.8145 - val_accuracy: 0.7563
# Epoch 26/100
# 80/80 [==============================] - 2s 21ms/step - loss: 0.0406 - accuracy: 0.9902 - val_loss: 0.8134 - val_accuracy: 0.7846
# Epoch 27/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.0433 - accuracy: 0.9866 - val_loss: 0.6977 - val_accuracy: 0.8145
# Epoch 28/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.0382 - accuracy: 0.9894 - val_loss: 0.5132 - val_accuracy: 0.8412
# Epoch 29/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.0292 - accuracy: 0.9941 - val_loss: 0.1910 - val_accuracy: 0.9481
# Epoch 30/100
# 80/80 [==============================] - 2s 23ms/step - loss: 0.0338 - accuracy: 0.9921 - val_loss: 0.2266 - val_accuracy: 0.9198
# Epoch 31/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.0274 - accuracy: 0.9937 - val_loss: 0.1659 - val_accuracy: 0.9575
# Epoch 32/100
# 80/80 [==============================] - 2s 21ms/step - loss: 0.0190 - accuracy: 0.9965 - val_loss: 0.2434 - val_accuracy: 0.9135
# Epoch 33/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.0280 - accuracy: 0.9917 - val_loss: 0.2912 - val_accuracy: 0.9119
# Epoch 34/100
# 80/80 [==============================] - 2s 23ms/step - loss: 0.0249 - accuracy: 0.9945 - val_loss: 0.3298 - val_accuracy: 0.8931
# Epoch 35/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.0269 - accuracy: 0.9937 - val_loss: 0.3066 - val_accuracy: 0.9214
# Epoch 36/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.0155 - accuracy: 0.9961 - val_loss: 0.1847 - val_accuracy: 0.9497
# Epoch 37/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.0198 - accuracy: 0.9961 - val_loss: 0.3742 - val_accuracy: 0.8962
# Epoch 38/100
# 80/80 [==============================] - 2s 21ms/step - loss: 0.0184 - accuracy: 0.9980 - val_loss: 0.2249 - val_accuracy: 0.9434
# Epoch 39/100
# 80/80 [==============================] - 2s 21ms/step - loss: 0.0327 - accuracy: 0.9914 - val_loss: 0.6846 - val_accuracy: 0.8333
# Epoch 40/100
# 80/80 [==============================] - 2s 21ms/step - loss: 0.0357 - accuracy: 0.9898 - val_loss: 1.9168 - val_accuracy: 0.6006
# Epoch 41/100
# 80/80 [==============================] - 2s 21ms/step - loss: 0.0202 - accuracy: 0.9965 - val_loss: 0.7917 - val_accuracy: 0.8318
# Epoch 42/100
# 80/80 [==============================] - 2s 23ms/step - loss: 0.0360 - accuracy: 0.9855 - val_loss: 0.2527 - val_accuracy: 0.9230
# Epoch 43/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.0277 - accuracy: 0.9933 - val_loss: 1.5425 - val_accuracy: 0.6761
# Epoch 44/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.0208 - accuracy: 0.9941 - val_loss: 0.2584 - val_accuracy: 0.9308
# Epoch 45/100
# 80/80 [==============================] - 2s 21ms/step - loss: 0.0115 - accuracy: 0.9980 - val_loss: 0.2106 - val_accuracy: 0.9403
# Epoch 46/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.0135 - accuracy: 0.9972 - val_loss: 1.0894 - val_accuracy: 0.7579
# Epoch 47/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.0189 - accuracy: 0.9949 - val_loss: 0.7258 - val_accuracy: 0.8333
# Epoch 48/100
# 80/80 [==============================] - 2s 21ms/step - loss: 0.0174 - accuracy: 0.9969 - val_loss: 0.5320 - val_accuracy: 0.8475
# Epoch 49/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.0137 - accuracy: 0.9969 - val_loss: 0.1925 - val_accuracy: 0.9465
# Epoch 50/100
# 80/80 [==============================] - 2s 22ms/step - loss: 0.0135 - accuracy: 0.9969 - val_loss: 0.3847 - val_accuracy: 0.8947
# Epoch 51/100
# 80/80 [==============================] - 2s 21ms/step - loss: 0.0122 - accuracy: 0.9965 - val_loss: 0.4099 - val_accuracy: 0.9025
# Epoch 51: early stopping

# %% [markdown]
# Evaluate the performance on the test set:

# %%
y_pred = model.predict(x_test_mfcc)

test_loss, test_acc = model.evaluate(x_test_mfcc,  y_test, verbose=2)
print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
# Out:
# 25/25 [==============================] - 0s 6ms/step
# 25/25 - 0s - loss: 0.3468 - accuracy: 0.8805 - 158ms/epoch - 6ms/step
# Test accuracy: 0.8805031180381775
# Test loss: 0.34678393602371216

# %%
plt.figure()
plt.plot(history_keras.history['accuracy'], label='Keras-Training')
plt.plot(history_keras.history['val_accuracy'], label='Keras-Validation')
plt.axhline(y=test_acc, xmin=0, xmax=epochs, linestyle='--', color='g', label='Keras-Test')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([1/num_speakers, 1])
plt.legend(loc='lower right')
plt.grid()
plt.title("Accuracy")
plt.show()

# %%
plt.figure()
plt.plot(history_keras.history['loss'], label='Keras-Training')
plt.plot(history_keras.history['val_loss'], label='Keras-Validation')
plt.axhline(y=test_loss, xmin=0, xmax=epochs, linestyle='--', color='g', label='Keras-Test')
plt.xlabel('Epoch')
plt.ylabel('Loss')
# plt.ylim([1/num_speakers, 1])
plt.legend(loc='upper left')
plt.grid()
plt.title(loss_fct)
plt.show()

# %%
from sklearn.metrics import confusion_matrix

y_pred_hard = np.argmax(y_pred, axis=1)
fig = plt.figure(figsize=(10,9))
cm = confusion_matrix(y_test, y_pred_hard, normalize='true')
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# Saving parameters

# %%
path = MODEL_DIR + f'{MODEL_NAME}/'
print(path)
if not os.path.exists(path):
    print("Creating directory for model : ", MODEL_NAME)
    os.makedirs(path)
    
model.save(path + MODEL_NAME + '.h5')
# Out:
# Models/8speakers/

# %%
# Show the model size for the non-quantized HDF5 model
h5_in_kb = os.path.getsize(MODEL_DIR + MODEL_NAME + '.h5') / 1024
print("Unquantized model file : ", MODEL_DIR + MODEL_NAME + '.h5')
print("HDF5 Model size without quantization: %d KB" % h5_in_kb)
# Out:
# Unquantized model file :  Models/8speakers/8speakers.h5
# HDF5 Model size without quantization: 326 KB

# %% [markdown]
# # TF Lite Conversion and Quantization:

# %%
print(train_set.numpy().shape)
# Out:
# (3180, 171, 13, 1)

# %%
tflite_model = tf_lite_conversion.convert_to_tf_lite(train_set,model,MODEL_DIR + TFLITE_MODEL_NAME)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\erolland\AppData\Local\Temp\tmpw3ziehjj\assets
# INFO:tensorflow:Assets written to: C:\Users\erolland\AppData\Local\Temp\tmpw3ziehjj\assets
# C:\Apps\Anaconda3\envs\ml\lib\site-packages\tensorflow\lite\python\convert.py:765: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "

# %%
# Show the model size for the non-quantized TFLite model
# Show the model size for the non-quantized HDF5 model
h5_in_kb = os.path.getsize(MODEL_DIR + MODEL_NAME + '.h5') / 1024
print("Unquantized model file : ", MODEL_DIR + MODEL_NAME + '.h5')
print("HDF5 Model size without quantization: %d KB" % h5_in_kb)

tflite_quant_in_kb = os.path.getsize(MODEL_DIR + TFLITE_MODEL_NAME + '.tflite') / 1024
print("\nQuantized model file : ", MODEL_DIR + TFLITE_MODEL_NAME + '.tflite')
print("TFLite Model size with 8-bit quantization: %d KB" % tflite_quant_in_kb)

# Determine the reduction in model size
print("\nReduction in model size by a factor of %f" % (h5_in_kb / tflite_quant_in_kb))
# Out:
# Unquantized model file :  Models/8speakers/8speakers.h5
# HDF5 Model size without quantization: 326 KB
#
# Quantized model file :  Models/8speakers/tflite_8speakers.tflite
# TFLite Model size with 8-bit quantization: 28 KB
#
# Reduction in model size by a factor of 11.565265

# %%
tflite_noquant_in_kb = os.path.getsize(MODEL_DIR + 'tf_lite_8speakers_no_quant.tflite') / 1024

print("\nQuantized model file : ", 'tf_lite_8speakers_no_quant.tflite')
print("TFLite Model size with 8-bit quantization: %d KB" % tflite_quant_in_kb)
# Out:
# Quantized model file :  tf_lite_8speakers_no_quant.tflite
# TFLite Model size with 8-bit quantization: 28 KB

# %% [markdown]
# # Performance evaluation

# %%
# Test the model using the tflite interpreter with quantization
# interpreter = tf.lite.Interpreter(model_path=path_tf_lite_q+"tf_lite_speaker_det0_quant.tflite")
interpreter = tf.lite.Interpreter(model_path=MODEL_DIR + 'tf_lite_8speakers_no_quant.tflite')
interpreter.allocate_tensors()

# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# print some information about the input and output tensors
print("Input shape is {} and of type {}".format(input_details[0]['shape'], input_details[0]['dtype']))
print("Output shape is {} and of type {}".format(output_details[0]['shape'], output_details[0]['dtype']))
# Out:
# Input shape is [  1 171  13   1] and of type <class 'numpy.int8'>
# Output shape is [1 8] and of type <class 'numpy.int8'>

# %%
predictions = np.zeros((len(test_set),), dtype=int)
input_scale, input_zero_point = input_details[0]["quantization"]
for i in range(len(test_set)):
    val_batch = test_set[i]
    val_batch = val_batch / input_scale + input_zero_point
    val_batch = np.expand_dims(val_batch, axis=0).astype(input_details[0]["dtype"])
    interpreter.set_tensor(input_details[0]['index'], val_batch)
    interpreter.allocate_tensors()
    interpreter.invoke()

    tflite_model_predictions = interpreter.get_tensor(output_details[0]['index'])
    #print("Prediction results shape:", tflite_model_predictions.shape)
    output = interpreter.get_tensor(output_details[0]['index'])
    predictions[i] = output.argmax()

# %%
from sklearn.metrics import accuracy_score

tflite_score = accuracy_score(y_test, predictions)
print("Accuracy of quantized to int8 model is {}%".format(tflite_score*100))
print("Compared to float32 accuracy of {}%".format(test_acc*100))
print("We have a change of {}%".format((tflite_score-test_acc)*100))
# Out:
# Accuracy of quantized to int8 model is 62.893081761006286%
# Compared to float32 accuracy of 88.05031180381775%
# We have a change of -25.157230042811463%

# %%
plt.figure(figsize=(10,9))
cm = confusion_matrix(y_test, predictions, 
                      normalize='true')
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
